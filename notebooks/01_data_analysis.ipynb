# %% [markdown]
# # 01 — Analyse des données
#
# Ce notebook utilise les données synthétiques fournies avec le dépôt.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
df = pd.read_csv(ROOT / "data/samples/sample_medqa_synthetic.csv")
df.head()

# %%
print("Nombre de paires :", len(df))
print("\nRépartition par catégorie :")
display(df["Category"].value_counts())
print("\nLongueur des réponses en mots :")
display(df["Answer"].str.split().str.len().describe())

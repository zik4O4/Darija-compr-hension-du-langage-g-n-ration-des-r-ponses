# %% [markdown]
# # 08 — Génération des réponses
#
# Le mode de démonstration fonctionne sans modèle. Le mode llama.cpp nécessite un serveur local.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.inference.generate import demo_answer

question = "واش الصداع ديما كيعني شي مرض خطير؟"
print(demo_answer(question))

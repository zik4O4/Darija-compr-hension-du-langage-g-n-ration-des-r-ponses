# %% [markdown]
# # 05 — Mistral 7B : préparation du Fine-Tuning

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.training.train_mistral import MODEL_ID
from src.training.common import DecoderTrainingConfig, print_training_plan
print_training_plan(DecoderTrainingConfig(MODEL_ID, "outputs/mistral"))
